# %% [markdown]
# # Thresholds and transformations

# %%
import cv2 as cv
import clue_boards
import matplotlib.pyplot as plt
import os

# %%
# A basic demonstration of the `clueboard_mask_from_frame` method
frame = cv.imread('sign.png')
flag, clueboard_image = clue_boards.clueboard_mask_from_frame(frame)
plt.imshow(clueboard_image)

# %%
clue_type_img = clueboard_image[35:115, 240:580]
clue_value_img = clueboard_image[255:335, 20:580]
plt.imshow(clue_type_img)

# %%
plt.imshow(clue_value_img)

# %%
path = os.path.join('test-images', 'good-clues', 'victim-kangaroo', 'testimg-029.jpg')
frame = cv.imread(path)
print(path)
frame.shape
# Out:
# test-images\good-clues\victim-kangaroo\testimg-029.jpg
# (168, 280, 3)

# %%
flag, clueboard_image = clue_boards.clueboard_mask_from_frame(frame)
plt.imshow(clueboard_image)

# %%
clue_type_img = clueboard_image[35:115, 240:580]
plt.imshow(clue_type_img)

# %%
clue_value_img = clueboard_image[255:335, 20:580]
plt.imshow(clue_value_img)

# %% [markdown]
# # Systematic testing: transform
